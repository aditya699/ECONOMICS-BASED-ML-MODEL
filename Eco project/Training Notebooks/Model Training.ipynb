# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv("C:/Users/aditya/Desktop/Eco project/data1.csv")

# %%
data.head()
# Out:
#   Country name  year  Life Ladder  Log GDP per capita  Social support  \
# 0  Afghanistan  2008         3.72                7.37            0.45
# 1  Afghanistan  2009         4.40                7.54            0.55
# 2  Afghanistan  2010         4.76                7.65            0.54
# 3  Afghanistan  2011         3.83                7.62            0.52
# 4  Afghanistan  2012         3.78                7.71            0.52
#
#    Healthy life expectancy at birth  Freedom to make life choices  Generosity  \
# 0                             50.80                          0.72        0.17
# 1                             51.20                          0.68        0.19
# 2                             51.60                          0.60        0.12
# 3                             51.92                          0.50        0.16
# 4                             52.24                          0.53        0.24
#
#    Perceptions of corruption  Positive affect  Negative affect
# ...

# %%
data.columns
# Out:
# Index(['Country name', 'year', 'Life Ladder', 'Log GDP per capita',
#        'Social support', 'Healthy life expectancy at birth',
#        'Freedom to make life choices', 'Generosity',
#        'Perceptions of corruption', 'Positive affect', 'Negative affect'],
#       dtype='object')

# %%
data_1=data[['Life Ladder','Log GDP per capita','Social support','Healthy life expectancy at birth','Freedom to make life choices','Generosity','Perceptions of corruption']]

# %%
data_1.head()
# Out:
#    Life Ladder  Log GDP per capita  Social support  \
# 0         3.72                7.37            0.45
# 1         4.40                7.54            0.55
# 2         4.76                7.65            0.54
# 3         3.83                7.62            0.52
# 4         3.78                7.71            0.52
#
#    Healthy life expectancy at birth  Freedom to make life choices  Generosity  \
# 0                             50.80                          0.72        0.17
# 1                             51.20                          0.68        0.19
# 2                             51.60                          0.60        0.12
# 3                             51.92                          0.50        0.16
# 4                             52.24                          0.53        0.24
#
#    Perceptions of corruption
# 0                       0.88
# 1                       0.85
# 2                       0.71
# 3                       0.73
# 4                       0.78

# %% [markdown]
# # REMOVING ALL NULL VALUES SINCE THEY ARE LESS IN NUMBER

# %%
data_1.dropna(inplace=True)

# %%
y=data_1['Life Ladder']
X=data_1.drop('Life Ladder',axis=1)

# %%
X.head()
# Out:
#    Log GDP per capita  Social support  Healthy life expectancy at birth  \
# 0                7.37            0.45                             50.80
# 1                7.54            0.55                             51.20
# 2                7.65            0.54                             51.60
# 3                7.62            0.52                             51.92
# 4                7.71            0.52                             52.24
#
#    Freedom to make life choices  Generosity  Perceptions of corruption
# 0                          0.72        0.17                       0.88
# 1                          0.68        0.19                       0.85
# 2                          0.60        0.12                       0.71
# 3                          0.50        0.16                       0.73
# 4                          0.53        0.24                       0.78

# %%
data_1.describe()
# Out:
#        Life Ladder  Log GDP per capita  Social support  \
# count      1712.00             1712.00         1712.00
# mean          5.45                9.32            0.81
# std           1.14                1.16            0.12
# min           2.38                6.63            0.29
# 25%           4.59                8.39            0.74
# 50%           5.36                9.46            0.83
# 75%           6.25               10.27            0.91
# max           7.97               11.65            0.99
#
#        Healthy life expectancy at birth  Freedom to make life choices  \
# count                           1712.00                       1712.00
# mean                              63.22                          0.74
# std                                7.68                          0.14
# min                               32.30                          0.26
# 25%                               58.18                          0.64
# ...

# %%
data_1.shape
# Out:
# (1712, 7)

# %%
df=X

# %%
df
# Out:
#       Log GDP per capita  Social support  Healthy life expectancy at birth  \
# 0                   7.37            0.45                             50.80
# 1                   7.54            0.55                             51.20
# 2                   7.65            0.54                             51.60
# 3                   7.62            0.52                             51.92
# 4                   7.71            0.52                             52.24
# ...                  ...             ...                               ...
# 1944                7.98            0.77                             54.40
# 1945                8.02            0.75                             55.00
# 1946                8.05            0.78                             55.60
# 1947                7.95            0.76                             56.20
# 1948                7.83            0.72                             56.80
#
# ...

# %%
data.columns
# Out:
# Index(['Country name', 'year', 'Life Ladder', 'Log GDP per capita',
#        'Social support', 'Healthy life expectancy at birth',
#        'Freedom to make life choices', 'Generosity',
#        'Perceptions of corruption', 'Positive affect', 'Negative affect'],
#       dtype='object')

# %%
df.columns=['Log GDP per capita','Social support','Healthy life expectancy at birth','Freedom to make life choices','Generosity','Perceptions of corruption']

# %%
df
# Out:
#       Log GDP per capita  Social support  Healthy life expectancy at birth  \
# 0                   7.37            0.45                             50.80
# 1                   7.54            0.55                             51.20
# 2                   7.65            0.54                             51.60
# 3                   7.62            0.52                             51.92
# 4                   7.71            0.52                             52.24
# ...                  ...             ...                               ...
# 1944                7.98            0.77                             54.40
# 1945                8.02            0.75                             55.00
# 1946                8.05            0.78                             55.60
# 1947                7.95            0.76                             56.20
# 1948                7.83            0.72                             56.80
#
# ...

# %% [markdown]
# # MULTICOLLLINEARITY

# %%
df.corr()
# Out:
#                                   Log GDP per capita  Social support  \
# Log GDP per capita                              1.00            0.71
# Social support                                  0.71            1.00
# Healthy life expectancy at birth                0.86            0.62
# Freedom to make life choices                    0.35            0.41
# Generosity                                     -0.03            0.06
# Perceptions of corruption                      -0.34           -0.23
#
#                                   Healthy life expectancy at birth  \
# Log GDP per capita                                            0.86
# Social support                                                0.62
# Healthy life expectancy at birth                              1.00
# Freedom to make life choices                                  0.38
# Generosity                                                    0.02
# Perceptions of corruption                                    -0.34
#
# ...

# %% [markdown]
# # SO BY SEEING AT CORRELATION MATRIX WE CAN SEE THAT THERE IS MULTICOLLINEARITY IN DATA

# %% [markdown]
# # In practice, usually, a VIF >5 or 10 indicates that the associated regression coefficients are poorly estimated because of multicollinearity

# %% [markdown]
# # Lets check for null values

# %%
df.isna().sum()
# Out:
# Log GDP per capita                  0
# Social support                      0
# Healthy life expectancy at birth    0
# Freedom to make life choices        0
# Generosity                          0
# Perceptions of corruption           0
# dtype: int64

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
  
# VIF dataframe
vif_data = pd.DataFrame()
vif_data["feature"] = X.columns
  
# calculating VIF for each feature
vif_data["VIF"] = [variance_inflation_factor(X.values, i)
                          for i in range(len(X.columns))]
  
print(vif_data)
# Out:
#                             feature    VIF
# 0                Log GDP per capita 312.23
# 1                    Social support  98.27
# 2  Healthy life expectancy at birth 263.95
# 3      Freedom to make life choices  37.74
# 4                        Generosity   1.19
# 5         Perceptions of corruption  12.21

# %% [markdown]
# # SO CLEARLY THE DATA SUFFERS FROM MULTICOLLINEARITY (SEVERE) IN THIS CASE

# %%
df.corr()
# Out:
#                                   Log GDP per capita  Social support  \
# Log GDP per capita                              1.00            0.71
# Social support                                  0.71            1.00
# Healthy life expectancy at birth                0.86            0.62
# Freedom to make life choices                    0.35            0.41
# Generosity                                     -0.03            0.06
# Perceptions of corruption                      -0.34           -0.23
#
#                                   Healthy life expectancy at birth  \
# Log GDP per capita                                            0.86
# Social support                                                0.62
# Healthy life expectancy at birth                              1.00
# Freedom to make life choices                                  0.38
# Generosity                                                    0.02
# Perceptions of corruption                                    -0.34
#
# ...

# %% [markdown]
# # This is very much expected since all are varaibles which collected country wise so of a country has one varible poor the same will happen in case of other variables and moreover economic variables ussally go in sync

# %%
df.columns
# Out:
# Index(['Log GDP per capita', 'Social support',
#        'Healthy life expectancy at birth', 'Freedom to make life choices',
#        'Generosity', 'Perceptions of corruption'],
#       dtype='object')

# %% [markdown]
# # SO LET'S DROP FEW VARIABLES WE WILL USE DOMAIN KNOWLEDGE TO DROP VARIABLES WE WILL KEEP Log GDP per capita  AND Freedom to make life choices AND Perceptions of corruption

# %%
df.drop(['Social support','Healthy life expectancy at birth','Generosity'],axis=1,inplace=True)

# %%
df.head()
# Out:
#    Log GDP per capita  Freedom to make life choices  Perceptions of corruption
# 0                7.37                          0.72                       0.88
# 1                7.54                          0.68                       0.85
# 2                7.65                          0.60                       0.71
# 3                7.62                          0.50                       0.73
# 4                7.71                          0.53                       0.78

# %%
df.corr()
# Out:
#                               Log GDP per capita  \
# Log GDP per capita                          1.00
# Freedom to make life choices                0.35
# Perceptions of corruption                  -0.34
#
#                               Freedom to make life choices  \
# Log GDP per capita                                    0.35
# Freedom to make life choices                          1.00
# Perceptions of corruption                            -0.49
#
#                               Perceptions of corruption
# Log GDP per capita                                -0.34
# Freedom to make life choices                      -0.49
# Perceptions of corruption                          1.00

# %% [markdown]
# # LET'S DROP ANOTHER VARIABLE I.E FREEDOM TO MAKE CHOICE

# %%
df.drop(['Freedom to make life choices'],axis=1,inplace =True)

# %%
df
# Out:
#       Log GDP per capita  Perceptions of corruption
# 0                   7.37                       0.88
# 1                   7.54                       0.85
# 2                   7.65                       0.71
# 3                   7.62                       0.73
# 4                   7.71                       0.78
# ...                  ...                        ...
# 1944                7.98                       0.72
# 1945                8.02                       0.75
# 1946                8.05                       0.84
# 1947                7.95                       0.83
# 1948                7.83                       0.79
#
# [1712 rows x 2 columns]

# %%
df.corr()
# Out:
#                            Log GDP per capita  Perceptions of corruption
# Log GDP per capita                       1.00                      -0.34
# Perceptions of corruption               -0.34                       1.00

# %%
X=df
from statsmodels.stats.outliers_influence import variance_inflation_factor
  
# VIF dataframe
vif_data = pd.DataFrame()
vif_data["feature"] = X.columns
  
# calculating VIF for each feature
vif_data["VIF"] = [variance_inflation_factor(X.values, i)
                          for i in range(len(X.columns))]
  
print(vif_data)
# Out:
#                      feature   VIF
# 0         Log GDP per capita 10.93
# 1  Perceptions of corruption 10.93

# %% [markdown]
# # SO U CAN SEE THAT VIF HAS CONSIDERBALY REDUCED

# %% [markdown]
# # THE REASON FOR DROPING THE VARAIBLES IS CLEAR THAT ECONOMIC VARIABLES GO IN SYNC SO I KEPT TWO VARIABLES WHICH INDEED WOULD EXPLAIN ALL OTHER VARIABLES

# %% [markdown]
# # MODEL TRAINING

# %% [markdown]
# # RATHER THEN USING JUST LINEAR REGRESSION LET'S FIT ALL MODELS AND THEN CHECK THE ACCURACY

# %%
from lazypredict.Supervised import LazyRegressor
from sklearn import datasets
from sklearn.utils import shuffle
import numpy as np

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.2, random_state=42)
# fit all models
reg = LazyRegressor(predictions=True)
models, predictions = reg.fit(X_train, X_test, y_train, y_test)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 42/42 [00:05<00:00,  7.59it/s]

# %%
print(models,predictions)
# Out:
#                                Adjusted R-Squared  R-Squared  RMSE  Time Taken
# Model
# HistGradientBoostingRegressor                0.69       0.70  0.62        0.41
# KNeighborsRegressor                          0.69       0.69  0.63        0.02
# RandomForestRegressor                        0.68       0.68  0.63        0.29
# GradientBoostingRegressor                    0.68       0.68  0.64        0.09
# AdaBoostRegressor                            0.68       0.68  0.64        0.04
# LGBMRegressor                                0.68       0.68  0.64        0.10
# ExtraTreesRegressor                          0.67       0.67  0.65        0.20
# BaggingRegressor                             0.66       0.66  0.65        0.04
# NuSVR                                        0.65       0.65  0.67        0.06
# SVR                                          0.64       0.65  0.67        0.07
# HuberRegressor                               0.64       0.64  0.67        0.02
# ...

# %% [markdown]
# # SO HERE WE FIND RANDOM FOREST REGRESSOR  IS GIVING THE BEST ACCRURACY( STANADARD MODELS KNOWN)

# %%
from sklearn.ensemble import RandomForestRegressor
  
 # create regressor object
regressor = RandomForestRegressor(n_estimators = 100, random_state = 0)
  
# fit the regressor with x and y data
regressor.fit(X, y)
# Out:
# RandomForestRegressor(random_state=0)

# %%
import pickle
filename = 'finalized_model.pickle'
pickle.dump(regressor, open(filename, 'wb'))

# %%
# %javascript
IPython.OutputArea.auto_scroll_threshold = 9999;
# Out:
# UsageError: Line magic function `%javascript` not found (But cell magic `%%javascript` exists, did you mean that instead?).

# %%
from IPython.core.display import display, HTML
display(HTML("<style>div.output_scroll { height: 44em; }</style>"))
# Out:
# <style>div.output_scroll { height: 44em; }</style>
